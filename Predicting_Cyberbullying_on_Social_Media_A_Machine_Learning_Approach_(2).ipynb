# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import re
import string
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers, models, losses, callbacks, regularizers, Input, Model
from tensorflow.keras.layers import (
    Embedding, LSTM, Dense, Dropout,
    Concatenate, Bidirectional, GlobalAveragePooling1D, Layer
)
from tensorflow.keras.callbacks import EarlyStopping
from keras.losses import BinaryFocalCrossentropy
from keras.regularizers import l2

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard  # Training callbacks


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

from imblearn.over_sampling import SMOTE

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Download NLTK assets

# %%
# Download NLTK assets
import nltk
try:
    nltk.data.find('corpora/wordnet')
except LookupError:
    nltk.download('wordnet')
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## DEfine Constant Variables

# %%
EMBEDDING_DIM = 256
KEY_DIM = 256
N_HEADS = 6
FEED_FORWARD_DIM = 1024
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 16 #32
EPOCHS = 10

# %% [markdown]
# ## Load Datasets

# %%
# !git clone "https://github.com/Brahmaswarup/Predicting-Cyberbullying-on-Social-Media--A-Machine-Learning-Approach.git"
# Out:
# fatal: destination path 'Predicting-Cyberbullying-on-Social-Media--A-Machine-Learning-Approach' already exists and is not an empty directory.

# %%
import pandas as pd

# %%
# Load necessary CSV files
# Please update the file paths below to match the location of your files in Google Drive
cb_labels_df = pd.read_csv("/content/Predicting-Cyberbullying-on-Social-Media--A-Machine-Learning-Approach/dataset/6. CB_Labels.csv")
users_df = pd.read_csv("/content/Predicting-Cyberbullying-on-Social-Media--A-Machine-Learning-Approach/dataset/1. users_data.csv")
communication_df = pd.read_csv("/content/Predicting-Cyberbullying-on-Social-Media--A-Machine-Learning-Approach/dataset/5. Communication_Data_Among_Users.csv")

# %%
users_df
# Out:
#     UserID  Age  Gender School Name  Grade
# 0        1   11  Others    School10      5
# 1        2   15    Male     School5      9
# 2        3   11    Male    School13      5
# 3        4   17    Male    School14     11
# 4        5   17    Male     School6     11
# ..     ...  ...     ...         ...    ...
# 95      96   13    Male    School10      7
# 96      97   14  Others     School8      8
# 97      98   10  Others    School15      4
# 98      99   11  Others     School1      5
# 99     100   17  Others     School5     11
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

users_numeric = users_df.select_dtypes(include=['number'])
users_corr = users_numeric.corr()
print("Correlation matrix for users_df:")
print(users_corr)
plt.figure(figsize=(10, 6))
sns.heatmap(users_corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap for users_df')
plt.show()
# Out:
# Correlation matrix for users_df:
#           UserID       Age     Grade
# UserID  1.000000 -0.155903 -0.155903
# Age    -0.155903  1.000000  1.000000
# Grade  -0.155903  1.000000  1.000000

# %%
cb_labels_df.head()
# Out:
#    User1 ID  User2 ID  Total_messages  Aggressive_Count  Intent_to_Harm  \
# 0         1         2              36                23        0.769444
# 1         1         3              16                 9        0.481250
# 2         1         4              17                 8        0.447794
# 3         1         5              24                15        0.612500
# 4         1         6              15                 7        0.420833
#
#    Peerness  CB_Label
# 0  0.500000         1
# 1  0.766667         1
# 2  0.366667         0
# 3  0.366667         0
# 4  0.433333         1

# %%
# @title Aggressive_Count

from matplotlib import pyplot as plt
cb_labels_df['Aggressive_Count'].plot(kind='hist', bins=20, title='Aggressive_Count')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
users_df.head()
# Out:
#    UserID  Age  Gender School Name  Grade
# 0       1   11  Others    School10      5
# 1       2   15    Male     School5      9
# 2       3   11    Male    School13      5
# 3       4   17    Male    School14     11
# 4       5   17    Male     School6     11

# %% [markdown]
# ## Merge Demographic and CB_Labels

# %%
# Merge user demographic info into CB_Labels
merged_df = cb_labels_df.merge(users_df, how='left', left_on='User1 ID', right_on='UserID', suffixes=('', '_User1'))
merged_df = merged_df.merge(users_df, how='left', left_on='User2 ID', right_on='UserID', suffixes=('', '_User2'))
merged_df.drop(columns=['UserID', 'UserID_User2'], inplace=True)

# %%
merged_df.head()
# Out:
#    User1 ID  User2 ID  Total_messages  Aggressive_Count  Intent_to_Harm  \
# 0         1         2              36                23        0.769444
# 1         1         3              16                 9        0.481250
# 2         1         4              17                 8        0.447794
# 3         1         5              24                15        0.612500
# 4         1         6              15                 7        0.420833
#
#    Peerness  CB_Label  Age  Gender School Name  Grade  Age_User2 Gender_User2  \
# 0  0.500000         1   11  Others    School10      5         15         Male
# 1  0.766667         1   11  Others    School10      5         11         Male
# 2  0.366667         0   11  Others    School10      5         17         Male
# 3  0.366667         0   11  Others    School10      5         17         Male
# 4  0.433333         1   11  Others    School10      5         16         Male
#
#   School Name_User2  Grade_User2
# 0           School5            9
# 1          School13            5
# 2          School14           11
# 3           School6           11
# 4          School12           10

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9511 entries, 0 to 9510
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User1 ID           9511 non-null   int64
#  1   User2 ID           9511 non-null   int64
#  2   Total_messages     9511 non-null   int64
#  3   Aggressive_Count   9511 non-null   int64
#  4   Intent_to_Harm     9511 non-null   float64
#  5   Peerness           4825 non-null   float64
#  6   CB_Label           9511 non-null   int64
#  7   Age                9511 non-null   int64
#  8   Gender             9511 non-null   object
#  9   School Name        9511 non-null   object
#  10  Grade              9511 non-null   int64
#  11  Age_User2          9511 non-null   int64
#  12  Gender_User2       9511 non-null   object
#  13  School Name_User2  9511 non-null   object
#  14  Grade_User2        9511 non-null   int64
# dtypes: float64(2), int64(9), object(4)
# memory usage: 1.1+ MB

# %%
merged_numeric = merged_df.select_dtypes(include=['number'])
merged_corr = merged_numeric.corr()
print("Correlation matrix for merged_df:")
print(merged_corr)
plt.figure(figsize=(12, 7))
sns.heatmap(merged_corr, annot=True, cmap='viridis', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap for merged_df')
plt.show()
# Out:
# Correlation matrix for merged_df:
#                   User1 ID  User2 ID  Total_messages  Aggressive_Count  \
# User1 ID          1.000000 -0.013985       -0.535505         -0.598036
# User2 ID         -0.013985  1.000000       -0.002944         -0.001294
# Total_messages   -0.535505 -0.002944        1.000000          0.881708
# Aggressive_Count -0.598036 -0.001294        0.881708          1.000000
# Intent_to_Harm   -0.571947  0.002850        0.717923          0.853553
# Peerness          0.012366  0.034397       -0.030649         -0.022142
# CB_Label         -0.416019  0.079925        0.556676          0.643575
# Age              -0.154555  0.003765        0.077691          0.088651
# Grade            -0.154555  0.003765        0.077691          0.088651
# Age_User2         0.002288 -0.154670       -0.009717         -0.015207
# Grade_User2       0.002288 -0.154670       -0.009717         -0.015207
#
#                   Intent_to_Harm  Peerness  CB_Label       Age     Grade  \
# User1 ID               -0.571947  0.012366 -0.416019 -0.154555 -0.154555
# User2 ID                0.002850  0.034397  0.079925  0.003765  0.003765
# Total_messages          0.717923 -0.030649  0.556676  0.077691  0.077691
# Aggressive_Count        0.853553 -0.022142  0.643575  0.088651  0.088651
# Intent_to_Harm          1.000000 -0.010015  0.514348  0.082294  0.082294
# Peerness               -0.010015  1.000000  0.213904 -0.132915 -0.132915
# CB_Label                0.514348  0.213904  1.000000  0.028574  0.028574
# Age                     0.082294 -0.132915  0.028574  1.000000  1.000000
# Grade                   0.082294 -0.132915  0.028574  1.000000  1.000000
# Age_User2              -0.008870  0.075459  0.002543 -0.010786 -0.010786
# Grade_User2            -0.008870  0.075459  0.002543 -0.010786 -0.010786
#
#                   Age_User2  Grade_User2
# User1 ID           0.002288     0.002288
# User2 ID          -0.154670    -0.154670
# Total_messages    -0.009717    -0.009717
# Aggressive_Count  -0.015207    -0.015207
# Intent_to_Harm    -0.008870    -0.008870
# Peerness           0.075459     0.075459
# CB_Label           0.002543     0.002543
# Age               -0.010786    -0.010786
# Grade             -0.010786    -0.010786
# Age_User2          1.000000     1.000000
# Grade_User2        1.000000     1.000000

# %% [markdown]
# ### Remove emojis, special characters, URLs, newline, etc

# %%
import string
# Remove emojis and special unicode characters
def strip_emoji(text):
    emoji_pattern = re.compile("["  # regex pattern for emojis and special symbols
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport symbols
        u"\U0001F1E0-\U0001F1FF"  # flags
        u"\U00002500-\U00002BEF"  # Chinese characters
        u"\U00002702-\U000027B0"  # dingbats, shapes
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642"
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"
        u"\u3030"
    "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# Remove newlines, links, non-ASCII characters, and most punctuation (keep /, \, .)
def strip_all_entities(text):
    text = text.replace('\r', '').replace('\n', ' ').lower()
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)
    text = re.sub(r'[^\x00-\x7f]', r'', text)
    punctuation_to_remove = string.punctuation.replace('/', '').replace('\\', '').replace('.', '') + 'Ã±ã¼â»§'
    table = str.maketrans('', '', punctuation_to_remove)
    text = text.translate(table)
    return text

# Remove trailing hashtags and strip # or _ from words mid-sentence
def clean_hashtags(text):
    new_text = " ".join(word.strip() for word in re.split('#(?!(?:hashtag)\b)[\w-]+(?=(?:\s+#[\w-]+)*\s*$)', text))
    new_text2 = " ".join(word.strip() for word in re.split('#|_', new_text))
    return new_text2

# Remove words containing special characters like $ and &
def filter_chars(a):
    sent = []
    for word in a.split(' '):
        if ('$' in word) | ('&' in word):
            sent.append('')
        else:
            sent.append(word)
    return ' '.join(sent)

# Remove extra whitespace
def remove_mult_spaces(text):
    return re.sub("\s\s+", " ", text)

# Remove date expressions and extra whitespace
def remove_dates_and_mult_spaces(text):
    text = re.sub(r'\b\d{1,2}[/-]\d{1,2}[/-]\d{2,4}\b', '', text)
    text = re.sub(r'\b\d{4}[/-]\d{1,2}[/-]\d{1,2}\b', '', text)
    text = re.sub(r'\b(?:jan|feb|mar|apr|may|jun|jul|aug|sep|oct|nov|dec)[a-z]*[\s\-.,]*\d{1,2}[\s\-.,]*\d{4}\b', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\s\s+', ' ', text)
    return text.strip()
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\w'
# <>:53: SyntaxWarning: invalid escape sequence '\s'
# <>:37: SyntaxWarning: invalid escape sequence '\w'
# <>:53: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2782977267.py:37: SyntaxWarning: invalid escape sequence '\w'
#   new_text = " ".join(word.strip() for word in re.split('#(?!(?:hashtag)\b)[\w-]+(?=(?:\s+#[\w-]+)*\s*$)', text))
# /tmp/ipython-input-2782977267.py:53: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub("\s\s+", " ", text)

# %%
import re

communication_df['Message1'] = (communication_df['Message']
                     .apply(strip_emoji)
                     .apply(remove_dates_and_mult_spaces)
                     .apply(strip_all_entities)
                     .apply(clean_hashtags)
                     .apply(filter_chars)
                     )

# %%
communication_df.head()
# Out:
#          Date   Time  User1 ID  User2 ID  \
# 0  2021-03-04  10:17         1         2
# 1  2022-01-24  04:27         1         2
# 2  2021-02-03  02:19         1         2
# 3  2021-09-04  08:54         1         2
# 4  2021-07-21  13:15         1         2
#
#                                              Message  Label  \
# 0  bye bye dear bajaj  i got some better work to ...      1
# 1  Haha your so funny you sit on wikipedia all da...      1
# 2  My problem is people talking out of their asse...      1
# 3                                    Article updated      0
# 4  Well arent you phucking special Its easy to ha...      1
#
#                                             Message1
# 0  bye bye dear bajaj i got some better work to d...
# 1  haha your so funny you sit on wikipedia all da...
# 2  my problem is people talking out of their asse...
# 3                                    article updated
# 4  well arent you phucking special its easy to ha...

# %%
df_comp = pd.DataFrame()

# Original text and its length
df_comp['pre-clean text'] = communication_df['Message']
df_comp['pre-clean len'] = communication_df['Message'].apply(lambda x: len(str(x).split()))

# Cleaned text and its length
df_comp['post-clean text'] = communication_df['Message1']
df_comp['post-clean len'] = communication_df['Message1'].apply(lambda x: len(str(x).split()))

df_comp.head(20)
# Out:
#                                        pre-clean text  pre-clean len  \
# 0   bye bye dear bajaj  i got some better work to ...             17
# 1   Haha your so funny you sit on wikipedia all da...             19
# 2   My problem is people talking out of their asse...             36
# 3                                     Article updated              2
# 4   Well arent you phucking special Its easy to ha...             21
# 5                    I THINK NAWLINWIKIS A HOMUNCULUS              5
# 6   Forwarding Is it considered bad etiquette to f...             15
# 7   hehehe lol thanx blud i like anoyin ppl coz i ...             33
# 8   Hey jerk we may do a deal please let in peace ...             44
# 9   WPBiography small   living  no class  stub pri...             16
# 10  Thanks   Not sure where to put this comment so...             79
# 11  why so scared of thurstan college colombo  kur...            130
# 12  your little brother the Yank  burning the Qura...             56
# 13                          U CUNT WHY DID U BLOCK ME              7
# 14  What happened to this article   Why has this a...             47
# 15  Keep quite you dumb ass the Wiki guidelines cl...            104
# 16             In fact it was just speedied as a hoax              9
# 17  The above user is a nutter and has been banned...             12
# 18                                 Kat the Rat\n\nMKR              4
# 19  Why yo angry   Wats up bro chill out and go to...             17
#
#                                       post-clean text  post-clean len
# 0   bye bye dear bajaj i got some better work to d...              17
# 1   haha your so funny you sit on wikipedia all da...              19
# 2   my problem is people talking out of their asse...              36
# 3                                     article updated               2
# 4   well arent you phucking special its easy to ha...              21
# 5                    i think nawlinwikis a homunculus               5
# 6   forwarding is it considered bad etiquette to f...              15
# 7   hehehe lol thanx blud i like anoyin ppl coz i ...              33
# 8   hey jerk we may do a deal please let in peace ...              44
# 9   wpbiography small living no class stub priorit...              16
# 10  thanks not sure where to put this comment so i...              79
# 11  why so scared of thurstan college colombo kuru...             130
# 12  your little brother the yank burning the quran...              56
# 13                          u cunt why did u block me               7
# 14  what happened to this article why has this art...              47
# 15  keep quite you dumb ass the wiki guidelines cl...             104
# 16             in fact it was just speedied as a hoax               9
# 17  the above user is a nutter and has been banned...              12
# 18                                    kat the rat mkr               4
# 19  why yo angry wats up bro chill out and go to i...              17

# %% [markdown]
# ### Remove Stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords



# Custom stopword removal using a manually defined list
def remove_stopwords_one(sentence):
    """
    Removes a list of custom-defined stopwords.
    """
    # Manually defined list of common stopwords
    stopwords = ["abnormal", "a", "ive","im", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up", "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves" ]
    # (full list truncated for brevity)

    sentence = sentence.lower()  # Convert to lowercase
    words = sentence.split()  # Split sentence into words
    no_words = [w for w in words if w not in stopwords]  # Remove stopwords
    sentence = " ".join(no_words)  # Reconstruct cleaned sentence

    return sentence

# Stopword removal using NLTK's standard stopwords list
def remove_stopwords(sentence):
    """
    Removes stopwords using NLTK's predefined English stopwords list.
    """
    stop_words = set(stopwords.words('english'))  # Load NLTK stopwords
    sentence = sentence.lower()  # Convert to lowercase
    words = sentence.split()  # Tokenize sentence
    no_words = [w for w in words if w not in stop_words]  # Remove stopwords
    sentence = " ".join(no_words)  # Rejoin words

    return sentence

# %%
communication_df['Message2'] = (communication_df['Message1'].apply(remove_stopwords_one)
                              .apply(remove_stopwords))

# %%
df_comp = pd.DataFrame()

# Original text and its length
df_comp['pre-clean text'] = communication_df['Message1']
df_comp['pre-clean len'] = communication_df['Message1'].apply(lambda x: len(str(x).split()))

# Cleaned text and its length
df_comp['post-clean text'] = communication_df['Message2']
df_comp['post-clean len'] = communication_df['Message2'].apply(lambda x: len(str(x).split()))

df_comp.head(20)
# Out:
#                                        pre-clean text  pre-clean len  \
# 0   bye bye dear bajaj i got some better work to d...             17
# 1   haha your so funny you sit on wikipedia all da...             19
# 2   my problem is people talking out of their asse...             36
# 3                                     article updated              2
# 4   well arent you phucking special its easy to ha...             21
# 5                    i think nawlinwikis a homunculus              5
# 6   forwarding is it considered bad etiquette to f...             15
# 7   hehehe lol thanx blud i like anoyin ppl coz i ...             33
# 8   hey jerk we may do a deal please let in peace ...             44
# 9   wpbiography small living no class stub priorit...             16
# 10  thanks not sure where to put this comment so i...             79
# 11  why so scared of thurstan college colombo kuru...            130
# 12  your little brother the yank burning the quran...             56
# 13                          u cunt why did u block me              7
# 14  what happened to this article why has this art...             47
# 15  keep quite you dumb ass the wiki guidelines cl...            104
# 16             in fact it was just speedied as a hoax              9
# 17  the above user is a nutter and has been banned...             12
# 18                                    kat the rat mkr              4
# 19  why yo angry wats up bro chill out and go to i...             17
#
#                                       post-clean text  post-clean len
# 0   bye bye dear bajaj got better work watching ur...              12
# 1   haha funny sit wikipedia day making sure every...              11
# 2   problem people talking asses fault people stup...              16
# 3                                     article updated               2
# 4   well arent phucking special easy things still ...              11
# 5                        think nawlinwikis homunculus               3
# 6   forwarding considered bad etiquette forward em...              10
# 7   hehehe lol thanx blud like anoyin ppl coz hav ...              24
# 8   hey jerk may deal please let peace articles ca...              27
# 9   wpbiography small living class stub priority l...              15
# 10  thanks sure put comment inappropriate remove t...              35
# 11  scared thurstan college colombo kurunduwatte c...              68
# 12  little brother yank burning quran pissing both...              26
# 13                                     u cunt u block               4
# 14  happened article article made inferior way ref...              20
# 15  keep quite dumb ass wiki guidelines clearly st...              61
# 16                                 fact speedied hoax               3
# 17                       user nutter banned wikipedia               4
# 18                                        kat rat mkr               3
# 19  yo angry wats bro chill go dnt know maybe ur a...              11

# %% [markdown]
# ### Lametization

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    # Tokenize the input text into individual words
    word_list = nltk.word_tokenize(text)

    # Apply lemmatization to each word and rejoin into a sentence
    lemmatized_output = ' '.join([lemmatizer.lemmatize(w) for w in word_list])

    return lemmatized_output

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
communication_df['Message3'] = communication_df['Message2'].apply(lemmatize_text)

# %%
df_comp = pd.DataFrame()

# Original text and its length
df_comp['pre-clean text'] = communication_df['Message2']
df_comp['pre-clean len'] = communication_df['Message2'].apply(lambda x: len(str(x).split()))

# Cleaned text and its length
df_comp['post-clean text'] = communication_df['Message3']
df_comp['post-clean len'] = communication_df['Message3'].apply(lambda x: len(str(x).split()))

df_comp.head(20)
# Out:
#                                        pre-clean text  pre-clean len  \
# 0   bye bye dear bajaj got better work watching ur...             12
# 1   haha funny sit wikipedia day making sure every...             11
# 2   problem people talking asses fault people stup...             16
# 3                                     article updated              2
# 4   well arent phucking special easy things still ...             11
# 5                        think nawlinwikis homunculus              3
# 6   forwarding considered bad etiquette forward em...             10
# 7   hehehe lol thanx blud like anoyin ppl coz hav ...             24
# 8   hey jerk may deal please let peace articles ca...             27
# 9   wpbiography small living class stub priority l...             15
# 10  thanks sure put comment inappropriate remove t...             35
# 11  scared thurstan college colombo kurunduwatte c...             68
# 12  little brother yank burning quran pissing both...             26
# 13                                     u cunt u block              4
# 14  happened article article made inferior way ref...             20
# 15  keep quite dumb ass wiki guidelines clearly st...             61
# 16                                 fact speedied hoax              3
# 17                       user nutter banned wikipedia              4
# 18                                        kat rat mkr              3
# 19  yo angry wats bro chill go dnt know maybe ur a...             11
#
#                                       post-clean text  post-clean len
# 0   bye bye dear bajaj got better work watching ur...              12
# 1   haha funny sit wikipedia day making sure every...              11
# 2   problem people talking ass fault people stupid...              16
# 3                                     article updated               2
# 4   well arent phucking special easy thing still l...              11
# 5                        think nawlinwikis homunculus               3
# 6   forwarding considered bad etiquette forward em...              10
# 7   hehehe lol thanx blud like anoyin ppl coz hav ...              24
# 8   hey jerk may deal please let peace article car...              27
# 9   wpbiography small living class stub priority l...              15
# 10  thanks sure put comment inappropriate remove t...              35
# 11  scared thurstan college colombo kurunduwatte c...              68
# 12  little brother yank burning quran pissing both...              26
# 13                                     u cunt u block               4
# 14  happened article article made inferior way ref...              20
# 15  keep quite dumb as wiki guideline clearly stat...              63
# 16                                 fact speedied hoax               3
# 17                       user nutter banned wikipedia               4
# 18                                        kat rat mkr               3
# 19  yo angry wats bro chill go dnt know maybe ur a...              11

# %%
communication_df.head()
# Out:
#          Date   Time  User1 ID  User2 ID  \
# 0  2021-03-04  10:17         1         2
# 1  2022-01-24  04:27         1         2
# 2  2021-02-03  02:19         1         2
# 3  2021-09-04  08:54         1         2
# 4  2021-07-21  13:15         1         2
#
#                                              Message  Label  \
# 0  bye bye dear bajaj  i got some better work to ...      1
# 1  Haha your so funny you sit on wikipedia all da...      1
# 2  My problem is people talking out of their asse...      1
# 3                                    Article updated      0
# 4  Well arent you phucking special Its easy to ha...      1
#
#                                             Message1  \
# 0  bye bye dear bajaj i got some better work to d...
# 1  haha your so funny you sit on wikipedia all da...
# 2  my problem is people talking out of their asse...
# 3                                    article updated
# 4  well arent you phucking special its easy to ha...
#
#                                             Message2  \
# 0  bye bye dear bajaj got better work watching ur...
# 1  haha funny sit wikipedia day making sure every...
# 2  problem people talking asses fault people stup...
# 3                                    article updated
# 4  well arent phucking special easy things still ...
#
#                                             Message3
# 0  bye bye dear bajaj got better work watching ur...
# 1  haha funny sit wikipedia day making sure every...
# 2  problem people talking ass fault people stupid...
# 3                                    article updated
# 4  well arent phucking special easy thing still l...

# %%
communication_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90356 entries, 0 to 90355
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      90356 non-null  object
#  1   Time      90356 non-null  object
#  2   User1 ID  90356 non-null  int64
#  3   User2 ID  90356 non-null  int64
#  4   Message   90356 non-null  object
#  5   Label     90356 non-null  int64
#  6   Message1  90356 non-null  object
#  7   Message2  90356 non-null  object
#  8   Message3  90356 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 6.2+ MB

# %% [markdown]
# ### Merge required columns

# %%
combined_df = pd.merge(communication_df, cb_labels_df[['User1 ID', 'User2 ID','Total_messages','Aggressive_Count', 'CB_Label','Intent_to_Harm']], on=['User1 ID', 'User2 ID'], how='inner')

# %%
combined_df.tail()
# Out:
#              Date   Time  User1 ID  User2 ID  \
# 90351  2021-11-21  11:55       100        98
# 90352  2021-05-11  14:39       100        99
# 90353  2021-11-17  18:47       100        99
# 90354  2021-06-07  14:11       100        99
# 90355  2021-11-03  02:07       100        99
#
#                                                  Message  Label  \
# 90351                  No youre right it was a lame idea      0
# 90352  break stuff   did you really break things when...      0
# 90353         Stifle You might like to consult this page      0
# 90354  Since the admin has already blocked MOVE of th...      0
# 90355  Ill apologize to terry but bear in mind that h...      0
#
#                                                 Message1  \
# 90351                  no youre right it was a lame idea
# 90352  break stuff did you really break things when y...
# 90353         stifle you might like to consult this page
# 90354  since the admin has already blocked move of th...
# 90355  ill apologize to terry but bear in mind that h...
#
#                                                 Message2  \
# 90351                              youre right lame idea
# 90352  break stuff really break things noticed name t...
# 90353                     stifle might like consult page
# 90354  since admin already blocked move article thing...
# 90355    ill apologize terry bear mind better shut quips
#
#                                                 Message3  Total_messages  \
# 90351                              youre right lame idea               6
# 90352  break stuff really break thing noticed name ta...               4
# 90353                     stifle might like consult page               4
# 90354  since admin already blocked move article thing...               4
# 90355     ill apologize terry bear mind better shut quip               4
#
#        Aggressive_Count  CB_Label  Intent_to_Harm
# 90351                 0         0           0.075
# 90352                 0         0           0.050
# 90353                 0         0           0.050
# 90354                 0         0           0.050
# 90355                 0         0           0.050

# %%
clean_com_df = combined_df[['User1 ID', 'User2 ID', 'Message3','Total_messages','Aggressive_Count','Intent_to_Harm', 'Label']]

# %%
clean_com_df.head()
# Out:
#    User1 ID  User2 ID                                           Message3  \
# 0         1         2  bye bye dear bajaj got better work watching ur...
# 1         1         2  haha funny sit wikipedia day making sure every...
# 2         1         2  problem people talking ass fault people stupid...
# 3         1         2                                    article updated
# 4         1         2  well arent phucking special easy thing still l...
#
#    Total_messages  Aggressive_Count  Intent_to_Harm  Label
# 0              36                23        0.769444      1
# 1              36                23        0.769444      1
# 2              36                23        0.769444      1
# 3              36                23        0.769444      0
# 4              36                23        0.769444      1

# %% [markdown]
# ### Compute 95th percentile length

# %%
# Compute sentence lengths
clean_com_df['sentence_length'] = clean_com_df['Message3'].apply(lambda x: len(x.split()))

# Basic statistics on sentence length
length_stats = clean_com_df["sentence_length"].describe()

# Plot distribution of sentence lengths by label
plt.figure(figsize=(10, 5))
for label in clean_com_df["Label"].unique():
    subset = clean_com_df[clean_com_df["Label"] == label]
    plt.hist(subset["sentence_length"], bins=30, alpha=0.5, label=label)
plt.title("Sentence Length Distribution by Class")
plt.xlabel("Sentence Length")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3757880592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_com_df['sentence_length'] = clean_com_df['Message3'].apply(lambda x: len(x.split()))

# %%
lengths = clean_com_df["sentence_length"].values  # or whatever column tracks length

# Choose 95th percentile length
MAX_LEN = int(np.percentile(lengths, 95))
print(MAX_LEN)
# Out:
# 106

# %%
clean_com_numeric = clean_com_df.select_dtypes(include=['number'])
clean_com_corr = clean_com_numeric.corr()
print("Correlation matrix for clean_com_df:")
print(clean_com_corr)
plt.figure(figsize=(10, 6))
sns.heatmap(clean_com_corr, annot=True, cmap='magma', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap for clean_com_df')
plt.show()
# Out:
# Correlation matrix for clean_com_df:
#                   User1 ID  User2 ID  Total_messages  Aggressive_Count  \
# User1 ID          1.000000 -0.010723       -0.663403         -0.692328
# User2 ID         -0.010723  1.000000       -0.008528         -0.006692
# Total_messages   -0.663403 -0.008528        1.000000          0.890999
# Aggressive_Count -0.692328 -0.006692        0.890999          1.000000
# Intent_to_Harm   -0.724320 -0.004798        0.863464          0.949835
# Label            -0.195589  0.000582        0.138135          0.246922
# sentence_length   0.008578 -0.001892       -0.001651         -0.008415
#
#                   Intent_to_Harm     Label  sentence_length
# User1 ID               -0.724320 -0.195589         0.008578
# User2 ID               -0.004798  0.000582        -0.001892
# Total_messages          0.863464  0.138135        -0.001651
# Aggressive_Count        0.949835  0.246922        -0.008415
# Intent_to_Harm          1.000000  0.293853        -0.010267
# Label                   0.293853  1.000000        -0.048760
# sentence_length        -0.010267 -0.048760         1.000000

# %% [markdown]
# ### Tokenization

# %%
from collections import Counter

# Tokenize the 'Message2' column (you can switch to any processed column)
tokenized_texts = clean_com_df['Message3'].astype(str).str.lower().str.split()

# Flatten the list of tokens
all_tokens = [token for sentence in tokenized_texts for token in sentence]
token_counts = Counter(all_tokens)

# Analyze token frequency
token_freqs = pd.DataFrame(token_counts.items(), columns=['token', 'count']).sort_values(by='count', ascending=False)
token_freqs['cumulative'] = token_freqs['count'].cumsum()
token_freqs['coverage'] = token_freqs['cumulative'] / token_freqs['count'].sum()

# Suggest VOCAB_SIZE to cover 99% of tokens
VOCAB_SIZE = token_freqs[token_freqs['coverage'] <= 0.99].shape[0]

# Suggest optimal BATCH_SIZE based on sentence length distribution
sentence_lengths = tokenized_texts.apply(len)
length_stats = sentence_lengths.describe()
BATCH_SIZE = 32 if length_stats['75%'] < 100 else 16  # heuristic

# %%
BATCH_SIZE
# Out:
# 32

# %%
clean_com_df['Label'].value_counts()
# Out:
# Label
# 0    59579
# 1    30777
# Name: count, dtype: int64

# %% [markdown]
# ### Visulize distribution of labels

# %%
import matplotlib.pyplot as plt

# Calculate the value counts of the 'category' column
category_counts = clean_com_df['Label'].value_counts()

# Bar chart
plt.figure(figsize=(6, 4))
category_counts.plot(kind='bar')
plt.xlabel('CB_Label')
plt.ylabel('Counts')
plt.title('Bar Chart of Counts')
plt.show()
print()

# Pie chart
plt.figure(figsize=(6, 4))
category_counts.plot(kind='pie', autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.title('Pie Chart of Distribution')

# Add legend
plt.legend()

plt.show()

# %%
clean_com_df.head()
# Out:
#    User1 ID  User2 ID                                           Message3  \
# 0         1         2  bye bye dear bajaj got better work watching ur...
# 1         1         2  haha funny sit wikipedia day making sure every...
# 2         1         2  problem people talking ass fault people stupid...
# 3         1         2                                    article updated
# 4         1         2  well arent phucking special easy thing still l...
#
#    Total_messages  Aggressive_Count  Intent_to_Harm  Label  sentence_length
# 0              36                23        0.769444      1               12
# 1              36                23        0.769444      1               11
# 2              36                23        0.769444      1               16
# 3              36                23        0.769444      0                2
# 4              36                23        0.769444      1               11

# %% [markdown]
# ## Compute aggression_ratio

# %%
#clean_com_df = communication_df[['User1 ID', 'User2 ID', 'Message2', 'Label']]
clean_com_df['aggression_ratio'] = clean_com_df['Aggressive_Count'] / clean_com_df['Total_messages'].replace(0, 1)

clean_com_df.head(100)
# Out:
# /tmp/ipython-input-2999425647.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_com_df['aggression_ratio'] = clean_com_df['Aggressive_Count'] / clean_com_df['Total_messages'].replace(0, 1)
#     User1 ID  User2 ID                                           Message3  \
# 0          1         2  bye bye dear bajaj got better work watching ur...
# 1          1         2  haha funny sit wikipedia day making sure every...
# 2          1         2  problem people talking ass fault people stupid...
# 3          1         2                                    article updated
# 4          1         2  well arent phucking special easy thing still l...
# ..       ...       ...                                                ...
# 95         1         6  kb tk hamara inch ke bom ko sambhalkar rkha ja...
# 96         1         6                                       random place
# 97         1         6  youre stupid blithering retard currently sitti...
# 98         1         6  pleasure frustration likely agenda pusher pres...
# 99         1         6  february please add nonsense wikipedia conside...
#
#     Total_messages  Aggressive_Count  Intent_to_Harm  Label  sentence_length  \
# 0               36                23        0.769444      1               12
# 1               36                23        0.769444      1               11
# 2               36                23        0.769444      1               16
# 3               36                23        0.769444      0                2
# 4               36                23        0.769444      1               11
# ..             ...               ...             ...    ...              ...
# 95              15                 7        0.420833      1               10
# 96              15                 7        0.420833      0                2
# 97              15                 7        0.420833      1               16
# 98              15                 7        0.420833      0                8
# 99              15                 7        0.420833      0               12
#
#     aggression_ratio
# 0           0.638889
# 1           0.638889
# 2           0.638889
# 3           0.638889
# 4           0.638889
# ..               ...
# 95          0.466667
# 96          0.466667
# 97          0.466667
# 98          0.466667
# 99          0.466667
#
# [100 rows x 9 columns]

# %%
clean_com_df2 = clean_com_df[['Message3','Label', 'Total_messages',	'Aggressive_Count','Intent_to_Harm']] #User1 ID', 'User2 ID',

# %%
# ================================
# Correlation Analysis and Heatmap
# ================================
# Check the correlation between numeric features and visualize with a heatmap.
import seaborn as sns  # For heatmap visualization

# Compute the correlation matrix for numeric features
corr_matrix = clean_com_df2[['Total_messages', 'Aggressive_Count', 'Intent_to_Harm']].corr()

# Print the correlation matrix
print("Correlation matrix:\n", corr_matrix)

# Plot the heatmap of the correlation matrix
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numeric Features')
plt.show()
# Out:
# Correlation matrix:
#                    Total_messages  Aggressive_Count  Intent_to_Harm
# Total_messages          1.000000          0.890999        0.863464
# Aggressive_Count        0.890999          1.000000        0.949835
# Intent_to_Harm          0.863464          0.949835        1.000000

# %% [markdown]
# ### Normalize Numeric Features

# %%
numeric_features = clean_com_df2[['Total_messages', 'Aggressive_Count','Intent_to_Harm']].fillna(0)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
normalized_features = scaler.fit_transform(numeric_features)

# %%
# Save the fitted StandardScaler
import pickle

with open("/content/drive/MyDrive/Project/scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

print("Saved scaler to /content/drive/MyDrive/Project/scaler.pkl")
# Out:
# Saved scaler to /content/drive/MyDrive/Project/scaler.pkl

# %%
print(type(normalized_features))             # should be <class 'numpy.ndarray'>
print(normalized_features.shape)             # should be (n_samples, 2)
print(normalized_features[:5])               # view the first 5 normalized rows
# Out:
# <class 'numpy.ndarray'>
# (90356, 3)
# [[2.42174285 3.59817582 2.52079056]
#  [2.42174285 3.59817582 2.52079056]
#  [2.42174285 3.59817582 2.52079056]
#  [2.42174285 3.59817582 2.52079056]
#  [2.42174285 3.59817582 2.52079056]]

# %% [markdown]
# ### Split Dataset

# %%
# Function to pad punctuation with spaces for better tokenization
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}, '\n'])", r" \1 ", s)  # Add spaces around punctuation
    s = re.sub(" +", " ", s)  # Replace multiple spaces with one
    return s

# Apply punctuation padding to each entry in the 'Message2' column
text_data = [pad_punctuation(x) for x in clean_com_df2['Message3']]

# Apply corrected mapping to labels
labels = clean_com_df2['Label']

# %%
# Efficient conversion
text_data = np.array(text_data, dtype=object)  # Prevents crash
labels = np.array(labels)

# Only do this if not already an array
# normalized_features = np.array(normalized_features)

# Get split indices once and use them for all
indices = np.arange(len(text_data))
train_idx, val_idx = train_test_split(indices, test_size=0.3, random_state=42)

# Apply splits
text_train, text_val = text_data[train_idx], text_data[val_idx]
label_train, label_val = labels[train_idx], labels[val_idx]
numeric_train, numeric_val = normalized_features[train_idx], normalized_features[val_idx]

# %%
BATCH_SIZE = 512

# %%
train_ds = tf.data.Dataset.from_tensor_slices(
    ({"text": text_train, "numeric": numeric_train}, label_train)
).batch(BATCH_SIZE).shuffle(1000)

val_ds = tf.data.Dataset.from_tensor_slices(
    ({"text": text_val, "numeric": numeric_val}, label_val)
).batch(BATCH_SIZE)

# %%
# Convert to pandas Series to use .isnull()
text_data_series = pd.Series(labels)

print("NaN values in text_data:", text_data_series.isnull().sum())
# Out:
# NaN values in text_data: 0

# %%
train_ds
# Out:
# <_ShuffleDataset element_spec=({'text': TensorSpec(shape=(None,), dtype=tf.string, name=None), 'numeric': TensorSpec(shape=(None, 3), dtype=tf.float64, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
val_ds
# Out:
# <_BatchDataset element_spec=({'text': TensorSpec(shape=(None,), dtype=tf.string, name=None), 'numeric': TensorSpec(shape=(None, 3), dtype=tf.float64, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ### Text Vectorization

# %%
# Create a TextVectorization layer to convert text into integer sequences
vectorize_layer = layers.TextVectorization(
    standardize="lower",            # Convert all text to lowercase
    max_tokens=VOCAB_SIZE,          # Limit vocabulary size
    output_mode="int",              # Output as integer token IDs
    output_sequence_length=MAX_LEN  # Pad/truncate all sequences to fixed length
)

# Prepare a dataset containing only the text (exclude labels)
#text_only_train_ds = train_ds.map(lambda x, y: x)
text_only_train_ds = train_ds.map(lambda x, y: x["text"])


# Adapt the vectorization layer to learn the vocabulary from the training data
vectorize_layer.adapt(text_only_train_ds)

# Retrieve the vocabulary learned from training data
vocab = vectorize_layer.get_vocabulary()

# %%
# Save TextVectorization vocabulary + config
import json

vocab = vectorize_layer.get_vocabulary()
vocab_path = "/content/drive/MyDrive/Project/vocab.txt"
with open(vocab_path, "w", encoding="utf-8") as f:
    f.write("\n".join(vocab))

tv_config = {
    "standardize": "lower",
    "max_tokens": int(VOCAB_SIZE),
    "output_mode": "int",
    "output_sequence_length": int(MAX_LEN),
}
with open("/content/drive/MyDrive/Project/tv_config.json", "w") as f:
    json.dump(tv_config, f)

print(f"Saved vocab to {vocab_path} ({len(vocab)} tokens)")
# Out:
# Saved vocab to /content/drive/MyDrive/Project/vocab.txt (114028 tokens)

# %% [markdown]
# ### Define Model

# %%
def prepare_inputs(inputs, labels):
    tokenized_text = vectorize_layer(inputs["text"])  # ✅ extract and vectorize text only
    return {"text": tokenized_text, "numeric": inputs["numeric"]}, labels


# Apply the function to transform both training and validation datasets
train_ds = train_ds.map(prepare_inputs)
val_ds = val_ds.map(prepare_inputs)

# Retrieve and print one example pair (tokenized input and corresponding label)
example_input_output = train_ds.take(1).get_single_element()

# %%
class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', threshold=0.3, **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.threshold = threshold
        self.precision = tf.keras.metrics.Precision(thresholds=self.threshold)
        self.recall = tf.keras.metrics.Recall(thresholds=self.threshold)

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + 1e-7))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
class_weight_dict = {0: 1.0, 1: 3.0}

# %%
#def get_callbacks(monitor_metric="val_f1_score", mode="max", patience=30, project_path="/kaggle/working/", threshold=None):
def get_callbacks(monitor_metric="val_f1_score", mode="max", patience=5, project_path="/content/drive/MyDrive/Project/"):
    """
    Returns a dictionary of standard Keras callbacks with customizable monitoring metric.

    Args:
        monitor_metric (str): Metric to monitor (e.g., 'val_loss', 'val_f1_score', 'val_recall_1').
        mode (str): 'max' to maximize (F1, recall) or 'min' to minimize (loss).
        patience (int): Number of epochs with no improvement before stopping or reducing LR.
        project_path (str): Base directory to store checkpoints and logs.

    Returns:
        dict: Dictionary of callbacks.
    """

    checkpoint_path = os.path.join(project_path, "checkpoint", "checkpoint.weights.h5")
    log_dir = os.path.join(project_path, "logs")

    callbacks = {
        "checkpoint": ModelCheckpoint(
            filepath=checkpoint_path,
            monitor=monitor_metric,
            mode=mode,
            save_best_only=True,
            save_weights_only=True,
            save_freq="epoch",
            verbose=1
        ),
        "early_stop": EarlyStopping(
            monitor=monitor_metric,
            mode=mode,
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),
        "lr_scheduler": ReduceLROnPlateau(
            monitor=monitor_metric,
            mode=mode,
            factor=0.2,
            patience=patience,
            min_lr=1e-6,
            verbose=1
        ),
        "tensorboard": TensorBoard(log_dir=log_dir)
    }


    return callbacks

# %%
# Set your metric target here
callbacks_dict = get_callbacks(monitor_metric="val_f1_score", mode="max")

# %% [markdown]
# **LSTM**

# %%
# Input layers
text_input = Input(shape=(MAX_LEN,), dtype=tf.int32, name="text")
numeric_input = Input(shape=(3,), dtype=tf.float32, name="numeric")  # 2 numeric features

# Embedding layer
embedding = Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_DIM, input_length=MAX_LEN)(text_input)

# LSTM processing
x = LSTM(128, return_sequences=False)(embedding)
x = Dropout(0.3)(x)

# Concatenate with numeric features
x = Concatenate()([x, numeric_input])

# Fully connected layers
x = Dense(64, activation="relu")(x)
x = Dropout(0.3)(x)
output = Dense(1, activation="sigmoid")(x)

# Define the model
lstm_model = Model(inputs={"text": text_input, "numeric": numeric_input}, outputs=output)

from keras.losses import BinaryFocalCrossentropy

lstm_model.compile(
    optimizer="adam",
    loss=BinaryFocalCrossentropy(gamma=2.0),
    metrics=[
        F1Score(threshold=0.3),
        tf.keras.metrics.Precision(thresholds=0.3),
        tf.keras.metrics.Recall(thresholds=0.3)
    ]
)

lstm_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ text (InputLayer)   │ (None, 106)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 106, 256)  │ 29,720,320 │ text[0][0]        │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 128)       │    197,120 │ embedding_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ numeric             │ (None, 3)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 131)       │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ numeric[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │      8,448 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64)        │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1)         │         65 │ dropout_4[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 29,925,953 (114.16 MB)
#  Trainable params: 29,925,953 (114.16 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
EPOCHS = 30

# %%
history = lstm_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    class_weight=class_weight_dict,
    callbacks=list(callbacks_dict.values())
)
# Out:
# Epoch 1/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - f1_score: 0.5099 - loss: 0.2620 - precision_5: 0.3422 - recall_5: 1.0000
# Epoch 1: val_f1_score improved from -inf to 0.50978, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 16s 106ms/step - f1_score: 0.5099 - loss: 0.2620 - precision_5: 0.3422 - recall_5: 1.0000 - val_f1_score: 0.5098 - val_loss: 0.1725 - val_precision_5: 0.3421 - val_recall_5: 0.9998 - learning_rate: 0.0010
# Epoch 2/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - f1_score: 0.5134 - loss: 0.2479 - precision_5: 0.3455 - recall_5: 0.9988
# Epoch 2: val_f1_score did not improve from 0.50978
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 15s 64ms/step - f1_score: 0.5134 - loss: 0.2479 - precision_5: 0.3455 - recall_5: 0.9987 - val_f1_score: 0.5063 - val_loss: 0.1654 - val_precision_5: 0.3389 - val_recall_5: 1.0000 - learning_rate: 0.0010
# Epoch 3/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - f1_score: 0.5126 - loss: 0.2403 - precision_5: 0.3447 - recall_5: 0.9998
# Epoch 3: val_f1_score improved from 0.50978 to 0.52343, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 12s 77ms/step - f1_score: 0.5127 - loss: 0.2403 - precision_5: 0.3448 - recall_5: 0.9998 - val_f1_score: 0.5234 - val_loss: 0.1549 - val_precision_5: 0.3545 - val_recall_5: 1.0000 - learning_rate: 0.0010
# Epoch 4/30
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - f1_score: 0.5213 - loss: 0.2420 - precision_5: 0.3526 - recall_5: 0.9991
# Epoch 4: val_f1_score did not improve from 0.52343
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - f1_score: 0.5213 - loss: 0.2421 - precision_5: 0.3526 - recall_5: 0.9991 - val_f1_score: 0.5202 - val_loss: 0.1688 - val_precision_5: 0.3515 - val_recall_5: 1.0000 - learning_rate: 0.0010
# Epoch 5/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - f1_score: 0.5240 - loss: 0.2485 - precision_5: 0.3550 - recall_5: 1.0000
# Epoch 5: val_f1_score improved from 0.52343 to 0.53862, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - f1_score: 0.5240 - loss: 0.2485 - precision_5: 0.3550 - recall_5: 1.0000 - val_f1_score: 0.5386 - val_loss: 0.1549 - val_precision_5: 0.3690 - val_recall_5: 0.9970 - learning_rate: 0.0010
# Epoch 6/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - f1_score: 0.5353 - loss: 0.2311 - precision_5: 0.3655 - recall_5: 0.9997
# Epoch 6: val_f1_score improved from 0.53862 to 0.54146, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - f1_score: 0.5353 - loss: 0.2311 - precision_5: 0.3656 - recall_5: 0.9997 - val_f1_score: 0.5415 - val_loss: 0.1500 - val_precision_5: 0.3718 - val_recall_5: 0.9958 - learning_rate: 0.0010
# Epoch 7/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - f1_score: 0.5431 - loss: 0.2168 - precision_5: 0.3729 - recall_5: 0.9995
# Epoch 7: val_f1_score improved from 0.54146 to 0.54257, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - f1_score: 0.5431 - loss: 0.2168 - precision_5: 0.3728 - recall_5: 0.9995 - val_f1_score: 0.5426 - val_loss: 0.1530 - val_precision_5: 0.3731 - val_recall_5: 0.9940 - learning_rate: 0.0010
# Epoch 8/30
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - f1_score: 0.5388 - loss: 0.2199 - precision_5: 0.3688 - recall_5: 0.9999
# Epoch 8: val_f1_score improved from 0.54257 to 0.54259, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - f1_score: 0.5389 - loss: 0.2199 - precision_5: 0.3688 - recall_5: 0.9998 - val_f1_score: 0.5426 - val_loss: 0.1525 - val_precision_5: 0.3732 - val_recall_5: 0.9937 - learning_rate: 0.0010
# Epoch 9/30
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - f1_score: 0.5460 - loss: 0.2424 - precision_5: 0.3756 - recall_5: 0.9997
# Epoch 9: val_f1_score did not improve from 0.54259
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - f1_score: 0.5459 - loss: 0.2424 - precision_5: 0.3755 - recall_5: 0.9997 - val_f1_score: 0.5404 - val_loss: 0.1695 - val_precision_5: 0.3711 - val_recall_5: 0.9938 - learning_rate: 0.0010
# Epoch 10/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - f1_score: 0.5534 - loss: 0.2263 - precision_5: 0.3829 - recall_5: 0.9980
# Epoch 10: val_f1_score improved from 0.54259 to 0.59733, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 17s 119ms/step - f1_score: 0.5536 - loss: 0.2261 - precision_5: 0.3831 - recall_5: 0.9980 - val_f1_score: 0.5973 - val_loss: 0.1034 - val_precision_5: 0.4281 - val_recall_5: 0.9880 - learning_rate: 0.0010
# Epoch 11/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - f1_score: 0.6694 - loss: 0.1218 - precision_5: 0.5054 - recall_5: 0.9916
# Epoch 11: val_f1_score improved from 0.59733 to 0.70177, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - f1_score: 0.6695 - loss: 0.1218 - precision_5: 0.5055 - recall_5: 0.9916 - val_f1_score: 0.7018 - val_loss: 0.0972 - val_precision_5: 0.5477 - val_recall_5: 0.9764 - learning_rate: 0.0010
# Epoch 12/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - f1_score: 0.7959 - loss: 0.0706 - precision_5: 0.6643 - recall_5: 0.9937
# Epoch 12: val_f1_score improved from 0.70177 to 0.76228, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 20s 117ms/step - f1_score: 0.7960 - loss: 0.0705 - precision_5: 0.6644 - recall_5: 0.9937 - val_f1_score: 0.7623 - val_loss: 0.0955 - val_precision_5: 0.6377 - val_recall_5: 0.9473 - learning_rate: 0.0010
# Epoch 13/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - f1_score: 0.8808 - loss: 0.0423 - precision_5: 0.7898 - recall_5: 0.9954
# Epoch 13: val_f1_score improved from 0.76228 to 0.78334, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 19s 107ms/step - f1_score: 0.8808 - loss: 0.0423 - precision_5: 0.7899 - recall_5: 0.9954 - val_f1_score: 0.7833 - val_loss: 0.1208 - val_precision_5: 0.6870 - val_recall_5: 0.9111 - learning_rate: 0.0010
# Epoch 14/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - f1_score: 0.9316 - loss: 0.0259 - precision_5: 0.8737 - recall_5: 0.9977
# Epoch 14: val_f1_score did not improve from 0.78334
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - f1_score: 0.9315 - loss: 0.0259 - precision_5: 0.8736 - recall_5: 0.9977 - val_f1_score: 0.7742 - val_loss: 0.1320 - val_precision_5: 0.6744 - val_recall_5: 0.9087 - learning_rate: 0.0010
# Epoch 15/30
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - f1_score: 0.9520 - loss: 0.0181 - precision_5: 0.9096 - recall_5: 0.9987
# Epoch 15: val_f1_score did not improve from 0.78334
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - f1_score: 0.9520 - loss: 0.0181 - precision_5: 0.9095 - recall_5: 0.9987 - val_f1_score: 0.7751 - val_loss: 0.2096 - val_precision_5: 0.6871 - val_recall_5: 0.8889 - learning_rate: 0.0010
# Epoch 16/30
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - f1_score: 0.9644 - loss: 0.0129 - precision_5: 0.9320 - recall_5: 0.9991
# Epoch 16: val_f1_score improved from 0.78334 to 0.78828, saving model to /content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - f1_score: 0.9643 - loss: 0.0129 - precision_5: 0.9320 - recall_5: 0.9991 - val_f1_score: 0.7883 - val_loss: 0.2220 - val_precision_5: 0.7281 - val_recall_5: 0.8594 - learning_rate: 0.0010
# Epoch 17/30
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - f1_score: 0.9762 - loss: 0.0092 - precision_5: 0.9539 - recall_5: 0.9996
# Epoch 17: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - f1_score: 0.9762 - loss: 0.0092 - precision_5: 0.9539 - recall_5: 0.9996 - val_f1_score: 0.7800 - val_loss: 0.2492 - val_precision_5: 0.7046 - val_recall_5: 0.8734 - learning_rate: 0.0010
# Epoch 18/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - f1_score: 0.9796 - loss: 0.0076 - precision_5: 0.9605 - recall_5: 0.9995
# Epoch 18: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 12s 69ms/step - f1_score: 0.9796 - loss: 0.0076 - precision_5: 0.9605 - recall_5: 0.9994 - val_f1_score: 0.7844 - val_loss: 0.2681 - val_precision_5: 0.7243 - val_recall_5: 0.8552 - learning_rate: 0.0010
# Epoch 19/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - f1_score: 0.9821 - loss: 0.0061 - precision_5: 0.9651 - recall_5: 0.9998
# Epoch 19: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - f1_score: 0.9821 - loss: 0.0061 - precision_5: 0.9651 - recall_5: 0.9998 - val_f1_score: 0.7815 - val_loss: 0.2906 - val_precision_5: 0.7137 - val_recall_5: 0.8636 - learning_rate: 0.0010
# Epoch 20/30
# 123/124 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - f1_score: 0.9816 - loss: 0.0067 - precision_5: 0.9645 - recall_5: 0.9994
# Epoch 20: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - f1_score: 0.9817 - loss: 0.0067 - precision_5: 0.9645 - recall_5: 0.9994 - val_f1_score: 0.7826 - val_loss: 0.3443 - val_precision_5: 0.7316 - val_recall_5: 0.8413 - learning_rate: 0.0010
# Epoch 21/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - f1_score: 0.9838 - loss: 0.0060 - precision_5: 0.9687 - recall_5: 0.9994
# Epoch 21: val_f1_score did not improve from 0.78828
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - f1_score: 0.9838 - loss: 0.0060 - precision_5: 0.9687 - recall_5: 0.9994 - val_f1_score: 0.7866 - val_loss: 0.3344 - val_precision_5: 0.7421 - val_recall_5: 0.8368 - learning_rate: 0.0010
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 16.

# %%
lstm_model.save("/content/drive/MyDrive/Project/lstm_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Get predictions (probabilities)
y_probs = lstm_model.predict(val_ds)
# Convert to class labels based on threshold (e.g., 0.3)
y_pred = (y_probs > 0.3).astype(int)


# Get corresponding true labels
y_true = []
for _, label in val_ds.unbatch():
    y_true.append(label.numpy())

y_true = np.array(y_true).astype(int)

print(classification_report(y_true, y_pred, target_names=["Non-Cyberbullying", "Cyberbullying"]))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#                    precision    recall  f1-score   support
#
# Non-Cyberbullying       0.92      0.84      0.88     17920
#     Cyberbullying       0.73      0.86      0.79      9187
#
#          accuracy                           0.84     27107
#         macro avg       0.82      0.85      0.83     27107
#      weighted avg       0.86      0.84      0.85     27107

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm1 = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))

labels = ['Non-Cyberbullying', 'Cyberbullying']  # replace with your actual class names

sns.heatmap(cm1, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)


plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
class AttentionLayer(Layer):
    def __init__(self, attention_dim):
        super(AttentionLayer, self).__init__()
        self.W = Dense(attention_dim, activation='tanh')  # learnable transformation
        self.V = Dense(1)  # projection to score

    def call(self, inputs):
        # inputs shape: (batch_size, sequence_length, hidden_dim)
        score = self.V(self.W(inputs))  # shape: (batch_size, sequence_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)  # shape: (batch_size, sequence_length, 1)

        context_vector = attention_weights * inputs  # shape: (batch_size, sequence_length, hidden_dim)
        context_vector = tf.reduce_sum(context_vector, axis=1)  # shape: (batch_size, hidden_dim)

        return context_vector  # final vector summarizing the sequence

# %% [markdown]
# **Bidirectional LSTM**

# %%
# Inputs
text_input = Input(shape=(MAX_LEN,), dtype=tf.int32, name="text")
numeric_input = Input(shape=(3,), dtype=tf.float32, name="numeric")

# Embedding
embedding = Embedding(input_dim=VOCAB_SIZE, output_dim=EMBEDDING_DIM)(text_input)

# BiLSTM
x = Bidirectional(LSTM(128, return_sequences=True))(embedding)

# Apply improved attention
context_vector = AttentionLayer(attention_dim=64)(x)

# Combine with numeric features
x = Concatenate()([context_vector, numeric_input])

# Dense layers
x = Dense(64, activation="relu", kernel_regularizer=l2(0.001))(x)
x = Dropout(0.3)(x)
output = Dense(1, activation="sigmoid")(x)

# Build model
bilstm_attention_model = Model(inputs={"text": text_input, "numeric": numeric_input}, outputs=output)

# %%
bilstm_attention_model.compile(
    optimizer="adam",
    loss=BinaryFocalCrossentropy(gamma=2.0),
    metrics=[
        F1Score(threshold=0.3),
        tf.keras.metrics.Precision(thresholds=0.3),
        tf.keras.metrics.Recall(thresholds=0.3)
    ]
)

bilstm_attention_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ text (InputLayer)   │ (None, 106)       │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 106, 256)  │ 29,720,320 │ text[0][0]        │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 106, 256)  │    394,240 │ embedding_3[0][0] │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_layer_1   │ (None, 256)       │     16,513 │ bidirectional_1[… │
# │ (AttentionLayer)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ numeric             │ (None, 3)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 259)       │          0 │ attention_layer_… │
# │ (Concatenate)       │                   │            │ numeric[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 64)        │     16,640 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 1)         │         65 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,147,778 (115.00 MB)
#  Trainable params: 30,147,778 (115.00 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = bilstm_attention_model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    class_weight=class_weight_dict,
    callbacks=list(callbacks_dict.values())
)
# Out:
# Epoch 1/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - f1_score: 0.5358 - loss: 0.2966 - precision_7: 0.3667 - recall_7: 0.9968
# Epoch 1: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 17s 111ms/step - f1_score: 0.5361 - loss: 0.2961 - precision_7: 0.3670 - recall_7: 0.9968 - val_f1_score: 0.6651 - val_loss: 0.1143 - val_precision_7: 0.5011 - val_recall_7: 0.9884 - learning_rate: 0.0010
# Epoch 2/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - f1_score: 0.7188 - loss: 0.1242 - precision_7: 0.5641 - recall_7: 0.9907
# Epoch 2: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - f1_score: 0.7188 - loss: 0.1241 - precision_7: 0.5641 - recall_7: 0.9907 - val_f1_score: 0.7278 - val_loss: 0.0939 - val_precision_7: 0.5814 - val_recall_7: 0.9726 - learning_rate: 0.0010
# Epoch 3/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - f1_score: 0.8308 - loss: 0.0727 - precision_7: 0.7132 - recall_7: 0.9949
# Epoch 3: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 21s 106ms/step - f1_score: 0.8307 - loss: 0.0727 - precision_7: 0.7132 - recall_7: 0.9949 - val_f1_score: 0.7245 - val_loss: 0.1015 - val_precision_7: 0.5814 - val_recall_7: 0.9611 - learning_rate: 0.0010
# Epoch 4/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - f1_score: 0.8836 - loss: 0.0460 - precision_7: 0.7934 - recall_7: 0.9974
# Epoch 4: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - f1_score: 0.8836 - loss: 0.0460 - precision_7: 0.7934 - recall_7: 0.9974 - val_f1_score: 0.7634 - val_loss: 0.1178 - val_precision_7: 0.6494 - val_recall_7: 0.9261 - learning_rate: 0.0010
# Epoch 5/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - f1_score: 0.9106 - loss: 0.0340 - precision_7: 0.8376 - recall_7: 0.9976
# Epoch 5: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 19s 102ms/step - f1_score: 0.9106 - loss: 0.0340 - precision_7: 0.8376 - recall_7: 0.9976 - val_f1_score: 0.7686 - val_loss: 0.1489 - val_precision_7: 0.6664 - val_recall_7: 0.9078 - learning_rate: 0.0010
# Epoch 6/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - f1_score: 0.9377 - loss: 0.0243 - precision_7: 0.8837 - recall_7: 0.9986
# Epoch 6: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - f1_score: 0.9377 - loss: 0.0243 - precision_7: 0.8837 - recall_7: 0.9986 - val_f1_score: 0.7800 - val_loss: 0.1519 - val_precision_7: 0.6937 - val_recall_7: 0.8908 - learning_rate: 0.0010
# Epoch 7/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - f1_score: 0.9550 - loss: 0.0179 - precision_7: 0.9152 - recall_7: 0.9985
# Epoch 7: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - f1_score: 0.9550 - loss: 0.0180 - precision_7: 0.9151 - recall_7: 0.9985 - val_f1_score: 0.7708 - val_loss: 0.1426 - val_precision_7: 0.6775 - val_recall_7: 0.8938 - learning_rate: 0.0010
# Epoch 8/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - f1_score: 0.9594 - loss: 0.0164 - precision_7: 0.9230 - recall_7: 0.9989
# Epoch 8: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - f1_score: 0.9594 - loss: 0.0164 - precision_7: 0.9229 - recall_7: 0.9989 - val_f1_score: 0.7872 - val_loss: 0.1677 - val_precision_7: 0.7291 - val_recall_7: 0.8552 - learning_rate: 0.0010
# Epoch 9/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - f1_score: 0.9699 - loss: 0.0125 - precision_7: 0.9429 - recall_7: 0.9984
# Epoch 9: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - f1_score: 0.9699 - loss: 0.0125 - precision_7: 0.9429 - recall_7: 0.9984 - val_f1_score: 0.7749 - val_loss: 0.2415 - val_precision_7: 0.6957 - val_recall_7: 0.8744 - learning_rate: 0.0010
# Epoch 10/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - f1_score: 0.9762 - loss: 0.0091 - precision_7: 0.9539 - recall_7: 0.9995
# Epoch 10: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - f1_score: 0.9762 - loss: 0.0091 - precision_7: 0.9539 - recall_7: 0.9995 - val_f1_score: 0.7750 - val_loss: 0.2640 - val_precision_7: 0.6948 - val_recall_7: 0.8760 - learning_rate: 0.0010
# Epoch 11/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - f1_score: 0.9810 - loss: 0.0083 - precision_7: 0.9633 - recall_7: 0.9994
# Epoch 11: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - f1_score: 0.9810 - loss: 0.0083 - precision_7: 0.9632 - recall_7: 0.9994 - val_f1_score: 0.7815 - val_loss: 0.2223 - val_precision_7: 0.7191 - val_recall_7: 0.8557 - learning_rate: 0.0010
# Epoch 12/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - f1_score: 0.9826 - loss: 0.0075 - precision_7: 0.9670 - recall_7: 0.9988
# Epoch 12: val_f1_score did not improve from 0.78828
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 20s 101ms/step - f1_score: 0.9826 - loss: 0.0075 - precision_7: 0.9669 - recall_7: 0.9988 - val_f1_score: 0.7689 - val_loss: 0.2981 - val_precision_7: 0.6869 - val_recall_7: 0.8731 - learning_rate: 0.0010
# Epoch 13/30
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - f1_score: 0.9848 - loss: 0.0066 - precision_7: 0.9706 - recall_7: 0.9995
# Epoch 13: val_f1_score did not improve from 0.78828
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 21s 102ms/step - f1_score: 0.9848 - loss: 0.0066 - precision_7: 0.9706 - recall_7: 0.9995 - val_f1_score: 0.7777 - val_loss: 0.2589 - val_precision_7: 0.7123 - val_recall_7: 0.8563 - learning_rate: 0.0010
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %%
bilstm_attention_model.save("/content/drive/MyDrive/Project/bilstm_attention_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Evaluate Model

# %%
# Get predictions (probabilities)
y_probs = bilstm_attention_model.predict(val_ds)
# Convert to class labels based on threshold (e.g., 0.3)
y_pred = (y_probs > 0.3).astype(int)


# Get corresponding true labels
y_true = []
for _, label in val_ds.unbatch():
    y_true.append(label.numpy())

y_true = np.array(y_true).astype(int)


print(classification_report(y_true, y_pred, target_names=["Non-Cyberbullying", "Cyberbullying"]))
# Out:
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
#                    precision    recall  f1-score   support
#
# Non-Cyberbullying       0.92      0.84      0.88     17920
#     Cyberbullying       0.73      0.86      0.79      9187
#
#          accuracy                           0.84     27107
#         macro avg       0.82      0.85      0.83     27107
#      weighted avg       0.85      0.84      0.85     27107

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))

labels = ['Non-Cyberbullying', 'Cyberbullying']  # replace with your actual class names

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)


plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Cyberbullying Detection using Hybrid Text and Numeric Features
#
# This notebook demonstrates a deep learning approach to detect cyberbullying using a combination of text data and numeric features. The project utilizes a dataset containing communication data between users, including message content, aggression counts, intent to harm scores, and demographic information.
#
# ## Dataset
# The dataset is loaded from the following CSV files, which are assumed to be located at `/content/Predicting-Cyberbullying-on-Social-Media--A-Machine-Learning-Approach/dataset/`:
# - `6. CB_Labels.csv`: Contains cyberbullying labels and related metrics.
# - `1. users_data.csv`: Contains user demographic information.
# - `5. Communication_Data_Among_Users.csv`: Contains communication details.
#
# ## Notebook Structure
# The notebook is organized into the following sections:
#
# 1.  **Library Imports**: Imports necessary libraries for data manipulation, visualization, and deep learning.
# 2.  **Download NLTK assets**: Downloads required NLTK data for text preprocessing.
# 3.  **Define Constant Variables**: Sets up constant variables for model parameters.
# 4.  **Load Datasets**: Loads the three CSV files into pandas DataFrames.
# 5.  **Merge Demographic and CB_Labels**: Merges user demographic information from `users_df` into `cb_labels_df`.
# 6.  **Remove emojis, special characters, URLs, newline, etc**: Defines and applies functions to clean the message text in `communication_df`.
# 7.  **Remove Stopwords**: Defines and applies functions to remove stopwords from the cleaned text.
# 8.  **Lemmatization**: Applies lemmatization to the text data.
# 9.  **Merge required columns**: Merges `communication_df` with selected columns from `cb_labels_df` and creates `clean_com_df`.
# 10. **Compute 95th percentile length**: Calculates the 95th percentile of sentence lengths in `clean_com_df['Message3']` to determine `MAX_LEN`.
# 11. **Compute aggression_ratio**: Calculates the ratio of aggressive messages to total messages and adds it as a new column to `clean_com_df`.
# 12. **Normalize Numeric Features**: Standardizes the numeric features (`Total_messages`, `Aggressive_Count`, `Intent_to_Harm`) from `clean_com_df2` using `StandardScaler`.
# 13. **Split Dataset**: Splits the processed text data (`clean_com_df2['Message3']`), normalized numeric features, and labels (`clean_com_df2['Label']`) into training and validation sets. Creates TensorFlow Datasets (`train_ds`, `val_ds`).
# 14. **Text Vectorization**: Creates and adapts a `TextVectorization` layer (`vectorize_layer`) to the text data in `train_ds` to create a vocabulary (`VOCAB_SIZE`).
# 15. **Define Model**: Defines two model architectures:
#     -   **LSTM**: A basic LSTM model (`lstm_model`) combining vectorized text and normalized numeric features.
#     -   **Bidirectional LSTM**: A Bidirectional LSTM model with a custom Attention mechanism (`bilstm_attention_model`), combining vectorized text and normalized numeric features.
# 16. **Train Model**: Trains the defined models using `train_ds` and `val_ds`, with a class weight dictionary (`class_weight_dict`) and callbacks (`callbacks_dict`).
# 17. **Evaluate Model**: Evaluates the trained models using `val_ds`, generates classification reports, and visualizes confusion matrices.
#
# ## Preprocessing Steps
#
# The text data undergoes the following preprocessing steps:
# -   Removal of emojis and special unicode characters using `strip_emoji`.
# -   Removal of dates and multiple spaces using `remove_dates_and_mult_spaces`.
# -   Removal of newlines, links, non-ASCII characters, and most punctuation using `strip_all_entities`.
# -   Cleaning of hashtags using `clean_hashtags`.
# -   Filtering of words containing special characters using `filter_chars`.
# -   Removal of custom and NLTK standard stopwords using `remove_stopwords_one` and `remove_stopwords`.
# -   Lemmatization using `lemmatize_text`.
# -   Padding punctuation with spaces using `pad_punctuation`.
#
# The numeric features (`Total_messages`, `Aggressive_Count`, `Intent_to_Harm`) are standardized using `StandardScaler`.
#
# ## Models
#
# Two deep learning models are implemented and evaluated:
#
# -   **LSTM Model**:
#     -   Takes text input (vectorized) and numeric input.
#     -   Uses an Embedding layer for text.
#     -   Processes text with an LSTM layer.
#     -   Concatenates the LSTM output with numeric features.
#     -   Uses Dense layers for classification.
#     -   Compiled with Adam optimizer, BinaryFocalCrossentropy loss, and F1Score, Precision, and Recall metrics with a threshold of 0.3.
#
# -   **Bidirectional LSTM with Attention Model**:
#     -   Similar input layers and Embedding as the LSTM model.
#     -   Uses a Bidirectional LSTM layer for text processing, capturing dependencies in both directions.
#     -   Applies a custom `AttentionLayer` to the BiLSTM output to focus on important parts of the sequence.
#     -   Concatenates the context vector from the Attention layer with numeric features.
#     -   Uses Dense layers with L2 regularization and Dropout for classification.
#     -   Compiled with Adam optimizer, BinaryFocalCrossentropy loss, and F1Score, Precision, and Recall metrics with a threshold of 0.3.
#
# ## Callbacks
# The following Keras callbacks are used during model training, monitoring `val_f1_score`:
# -   `ModelCheckpoint`: Saves the best model weights to `/content/drive/MyDrive/Project/checkpoint/checkpoint.weights.h5`.
# -   `EarlyStopping`: Stops training if `val_f1_score` does not improve for 5 epochs.
# -   `ReduceLROnPlateau`: Reduces the learning rate if `val_f1_score` does not improve for 5 epochs.
# -   `TensorBoard`: Logs training progress to `/content/drive/MyDrive/Project/logs`.
#
# ## Evaluation
# The models are evaluated using:
# -   Classification Report: Provides precision, recall, and F1-score for each class.
# -   Confusion Matrix: Visualizes the true vs. predicted labels using `seaborn.heatmap`.
#
# The F1Score metric is used with a threshold of 0.3 for evaluation.
#
# ## How to Run
# 1. Ensure the dataset files are located at `/content/Predicting-Cyberbullying-on-Social-Media--A-Machine-Learning-Approach/dataset/`.
# 2. Ensure you have a directory at `/content/drive/MyDrive/Project/` for saving model checkpoints and logs.
# 3. Run the notebook cells sequentially.
#
# ## Dependencies
# The notebook requires the following libraries:
# -   pandas
# -   numpy
# -   matplotlib
# -   seaborn
# -   tensorflow
# -   scikit-learn
# -   imblearn
# -   nltk
#
# These dependencies are imported at the beginning of the notebook. Ensure you have these libraries installed in your environment. NLTK assets (`wordnet`, `punkt`, `stopwords`) are downloaded within the notebook.
